# %% [markdown]
# Tinder have run an experiment to understand what makes people interested into each other
#
# Goals 🎯
# Use the dataset to understand what makes people interested into each other to go on a second date together:
# You may use descriptive statistics - You may use visualisations
#
# Data was gathered from participants in experimental speed dating events from 2002-2004. During the events, the attendees would have a four minute "first date" with every other participant of the opposite sex. At the end of their four minutes, participants were asked if they would like to see their date again. They were also asked to rate their date on six attributes: Attractiveness, Sincerity, Intelligence, Fun, Ambition, and Shared Interests.

# %% [markdown]
# Preprocessing

# %%
import pandas as pd
pd.options.display.max_columns = None

# %%
import plotly.express as px 
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
tinder_df=pd.read_csv('Speed+Dating+Data.csv',encoding='unicode_escape')

# %%
tinder_df.shape
# Out:
# (8378, 195)

# %%
tinder_df.head()
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4
# 1    1  1.0       0    1       1     1     10         7       NaN      3
# 2    1  1.0       0    1       1     1     10         7       NaN     10
# 3    1  1.0       0    1       1     1     10         7       NaN      5
# 4    1  1.0       0    1       1     1     10         7       NaN      7
#
#    partner   pid  match  int_corr  samerace  age_o  race_o  pf_o_att  \
# 0        1  11.0      0      0.14         0   27.0     2.0      35.0
# 1        2  12.0      0      0.54         0   22.0     2.0      60.0
# 2        3  13.0      1      0.16         1   22.0     4.0      19.0
# 3        4  14.0      1      0.61         0   23.0     2.0      30.0
# 4        5  15.0      1      0.21         0   24.0     3.0      30.0
#
#    pf_o_sin  pf_o_int  pf_o_fun  pf_o_amb  pf_o_sha  dec_o  attr_o  sinc_o  \
# ...

# %% [markdown]
# Deliverable 📬
#
# To complete this project, your team should deliver:
#
# A notebook with:
#
# descriptive statistics
# visualisations
# captions and interpretations on how the stats and visualisations are relevant to why people agree to a second date
#
# -------
#
# Problématique:
# est-ce que tinder répond à la demande de personnes en recherche de partenaire sérieux?
# est-ce que les facteurs de matching changent en fonction du temps? jeunes vs vieux

# %%
tinder_profils = tinder_df[['iid', 'gender', 'idg', 'age', 
                            'field', 'field_cd', 'career', 'career_c',
                            'undergra', 'mn_sat', 'tuition', 'race', 
                            'imprace', 'imprelig', 'from', 'zipcode', 
                            'income', 'goal', 'date', 'go_out', 
                            'sports', 'tvsports', 'exercise', 'dining',
                            'museums', 'art', 'hiking', 'gaming', 'clubbing', 
                            'reading', 'tv', 'theater', 'movies', 'concerts', 
                            'music', 'shopping', 'yoga', 'exphappy', 'expnum']]

tinder_profils_activities=tinder_df[['sports', 'tvsports', 'exercise', 'dining',
                            'museums', 'art', 'hiking', 'gaming', 'clubbing', 
                            'reading', 'tv', 'theater', 'movies', 'concerts', 
                            'music', 'shopping', 'yoga', 'exphappy', 'expnum']]

# %%
tinder_profils_gender=tinder_profils['gender'].value_counts().reset_index()
tinder_profils_gender['gender'] = tinder_profils_gender['gender'].replace({1: 'man', 0: 'woman'})

fig = px.pie(tinder_profils_gender,values='count',names='gender',
             title='Distribution des genres - Tinder Experience',
             width=400)

fig.show()

# %%
fig = make_subplots(rows=6,cols=1)
fig.add_trace(
    go.Histogram(
        x = tinder_profils['age'],
        name = 'age'),
    row=1,
    col=1)

fig.add_trace(
    go.Histogram(
        x = tinder_profils['race'],
        name = 'race'),
    row=2,
    col=1)

fig.add_trace(
    go.Histogram(
        x = tinder_profils['imprace'],
        name = 'imprace'),
    row=3,
    col=1)

fig.add_trace(
    go.Histogram(
        x = tinder_profils['goal'],
        name = 'goal'),
    row=4,
    col=1)

fig.add_trace(
    go.Histogram(
        x = tinder_profils['date'],
        name = 'date'),
    row=5,
    col=1)

fig.add_trace(
    go.Histogram(
        x = tinder_profils['expnum'],
        name = 'expnum'),
    row=6,
    col=1)

fig.update_layout(width=700,height=1000)
fig.show()

# %%
fig = px.box(tinder_profils, x='income', title='Distribution des revenus', 
                   width=700, height=400)
fig.show()

# %%
tinder_from=tinder_profils['from'].value_counts().reset_index()
tinder_from = tinder_from[tinder_from['count'] > 100]
fig=px.bar(tinder_from,x='from',y='count')
fig.show()

# %%
tinder_profils_activities
# Out:
#       sports  tvsports  exercise  dining  museums   art  hiking  gaming  \
# 0        9.0       2.0       8.0     9.0      1.0   1.0     5.0     1.0
# 1        9.0       2.0       8.0     9.0      1.0   1.0     5.0     1.0
# 2        9.0       2.0       8.0     9.0      1.0   1.0     5.0     1.0
# 3        9.0       2.0       8.0     9.0      1.0   1.0     5.0     1.0
# 4        9.0       2.0       8.0     9.0      1.0   1.0     5.0     1.0
# ...      ...       ...       ...     ...      ...   ...     ...     ...
# 8373     8.0       2.0       5.0    10.0     10.0  10.0     7.0     1.0
# 8374     8.0       2.0       5.0    10.0     10.0  10.0     7.0     1.0
# 8375     8.0       2.0       5.0    10.0     10.0  10.0     7.0     1.0
# 8376     8.0       2.0       5.0    10.0     10.0  10.0     7.0     1.0
# 8377     8.0       2.0       5.0    10.0     10.0  10.0     7.0     1.0
#
#       clubbing  reading   tv  theater  movies  concerts  music  shopping  \
# ...
